# %%
import os
import json
from pprint import pprint

import numpy as np
import pandas as pd

import datetime

# %%
def get_track_data(item):
    track = {}
    track['played_at'] = item['played_at']
    track['name'] = item['track']['name']
    track['duration_ms'] = item['track']['duration_ms']
    track['id'] = item['track']['id']
    track['popularity'] = item['track']['popularity']
    track['artist'] = ' '.join(sorted([artist['name'] for artist in item['track']['artists']]))
    track['album'] = item['track']['album']['name']   
    track['album_id'] = item['track']['album']['id']
    
    return track

# %%
def get_track_feature_data(item):
    audio_features = ['id',
                      'acousticness', 
                      'danceability', 
                      'energy', 
                      'instrumentalness', 
                      'liveness', 
                      'loudness', 
                      'speechiness',
                      'tempo',
                      'valence',
                      'key',
                      'mode', 
                      'time_signature']

    return {feature: item[feature] for feature in audio_features}

# %%
data_dir = '../data/'

# %%
tracks = []
features = []
for file in os.listdir(data_dir):
    filename = os.fsdecode(file)
    if filename.endswith('.json'):
        with open(os.path.join(os.fsdecode(data_dir), filename), 'r') as f:
            data_json = json.load(f)
            if filename.startswith('recently'):
                for item in data_json['items']:
                    track = get_track_data(item)
                    tracks.append(track)
                    
            elif filename.startswith('audio'):
                for item in data_json.values():
                    track_feature = get_track_feature_data(item[0])
                    features.append(track_feature)

# %%
tracks = pd.DataFrame(tracks)
tracks.drop_duplicates(inplace=True)
tracks.shape
# Out:
# (3106, 8)

# %%
tracks.head()
# Out:
#                   played_at            name  duration_ms  \
# 0  2019-12-12T10:57:09.063Z  Trans Siberian       472769
# 1  2019-12-12T10:49:16.309Z      Guillotine       417761
# 2  2019-12-12T10:42:18.604Z       Invisible       525548
# 3  2019-12-12T10:33:32.932Z  Final Frontier       602813
# 4  2019-12-11T20:55:29.018Z          O pato       122866
#
#                        id  popularity         artist  \
# 0  2mSCnlqQ0mvHrPyVLuo5kE          18   Juno Reactor
# 1  0m6n7veetHyEr3NuUreI4h          20   Juno Reactor
# 2  3Jw9OuPa9AXjaJXKbic26y          21   Juno Reactor
# 3  78WeMIirolQgyaUqFnqOCi          26   Juno Reactor
# 4  6u6E9DZgzyyo1oFofn7zIs          45  João Gilberto
#
#                               album                album_id
# 0  The Golden Sun of the Great East  4cgvNUnZM2QHxhhY12lWk7
# 1  The Golden Sun of the Great East  4cgvNUnZM2QHxhhY12lWk7
# 2  The Golden Sun of the Great East  4cgvNUnZM2QHxhhY12lWk7
# 3  The Golden Sun of the Great East  4cgvNUnZM2QHxhhY12lWk7
# 4             Bossa Nova Essentials  2hVlKPHcnN1xpdnIQOfTfi

# %%
features = pd.DataFrame(features)
features.drop_duplicates(inplace=True)
features.shape
# Out:
# (1717, 13)

# %%
features.head()
# Out:
#                        id  acousticness  danceability  energy  \
# 0  03d5V0uvYp3hU7wE9mJzJa      0.022500         0.454   0.447
# 1  0CufyIMTfy8YFJXjNfDXvl      0.528000         0.326   0.279
# 2  121IyQ9weu5MXAfXAFVDcH      0.000334         0.454   0.579
# 3  1Nc5cKez6FmEbsFwYwUbqg      0.795000         0.527   0.825
# 4  1TbgAIgWDO1qzwem0g0Qyy      0.877000         0.487   0.659
#
#    instrumentalness  liveness  loudness  speechiness    tempo  valence  key  \
# 0           0.88900    0.1030   -13.387       0.0273   74.474    0.429    9
# 1           0.69600    0.2220   -15.306       0.0336  136.480    0.148    7
# 2           0.00625    0.1630    -9.987       0.0286   84.146    0.221    0
# 3           0.00000    0.0973    -5.025       0.0939   95.958    0.772    3
# 4           0.31100    0.1340   -10.989       0.0540  107.135    0.854   10
#
#    mode  time_signature
# 0     0               4
# 1     1               4
# 2     1               4
# 3     1               4
# 4     0               4

# %%
tracks.to_csv('../data/processed/tracks.csv')
features.to_csv('../data/processed/track_features.csv')
